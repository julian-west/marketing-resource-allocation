# %% [markdown]
# <p style="font-size:29px"><strong>Retail Marketing Individual Assignment</strong></p>
#
# Analysis notebook for final model.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></span></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Dataset-characteristics" data-toc-modified-id="Dataset-characteristics-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Dataset characteristics</a></span></li><li><span><a href="#Dataset-features" data-toc-modified-id="Dataset-features-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Dataset features</a></span></li><li><span><a href="#Seasonality" data-toc-modified-id="Seasonality-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Seasonality</a></span></li></ul></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Preparation</a></span><ul class="toc-item"><li><span><a href="#Log-Transformation" data-toc-modified-id="Log-Transformation-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Log Transformation</a></span></li><li><span><a href="#Seasonal-Dummy-Variables" data-toc-modified-id="Seasonal-Dummy-Variables-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Seasonal Dummy Variables</a></span></li><li><span><a href="#Binary-Variables" data-toc-modified-id="Binary-Variables-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Binary Variables</a></span></li><li><span><a href="#Train/test-Split" data-toc-modified-id="Train/test-Split-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Train/test Split</a></span></li><li><span><a href="#Save-Processed-Data" data-toc-modified-id="Save-Processed-Data-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Save Processed Data</a></span></li></ul></li><li><span><a href="#SCAN*PRO-Regression" data-toc-modified-id="SCAN*PRO-Regression-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>SCAN*PRO Regression</a></span><ul class="toc-item"><li><span><a href="#Train/validation" data-toc-modified-id="Train/validation-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Train/validation</a></span><ul class="toc-item"><li><span><a href="#Brand-1" data-toc-modified-id="Brand-1-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Brand 1</a></span><ul class="toc-item"><li><span><a href="#Model-Estimation" data-toc-modified-id="Model-Estimation-5.1.1.1"><span class="toc-item-num">5.1.1.1&nbsp;&nbsp;</span>Model Estimation</a></span></li><li><span><a href="#Model-Diagnostics" data-toc-modified-id="Model-Diagnostics-5.1.1.2"><span class="toc-item-num">5.1.1.2&nbsp;&nbsp;</span>Model Diagnostics</a></span></li><li><span><a href="#Model-Validation" data-toc-modified-id="Model-Validation-5.1.1.3"><span class="toc-item-num">5.1.1.3&nbsp;&nbsp;</span>Model Validation</a></span></li></ul></li><li><span><a href="#Brand-2" data-toc-modified-id="Brand-2-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Brand 2</a></span><ul class="toc-item"><li><span><a href="#Model-Estimation" data-toc-modified-id="Model-Estimation-5.1.2.1"><span class="toc-item-num">5.1.2.1&nbsp;&nbsp;</span>Model Estimation</a></span></li><li><span><a href="#Model-Diagnostics" data-toc-modified-id="Model-Diagnostics-5.1.2.2"><span class="toc-item-num">5.1.2.2&nbsp;&nbsp;</span>Model Diagnostics</a></span></li><li><span><a href="#Model-Validation" data-toc-modified-id="Model-Validation-5.1.2.3"><span class="toc-item-num">5.1.2.3&nbsp;&nbsp;</span>Model Validation</a></span></li></ul></li><li><span><a href="#Brand-3" data-toc-modified-id="Brand-3-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Brand 3</a></span><ul class="toc-item"><li><span><a href="#Model-Estimation" data-toc-modified-id="Model-Estimation-5.1.3.1"><span class="toc-item-num">5.1.3.1&nbsp;&nbsp;</span>Model Estimation</a></span></li><li><span><a href="#Model-Diagnostics" data-toc-modified-id="Model-Diagnostics-5.1.3.2"><span class="toc-item-num">5.1.3.2&nbsp;&nbsp;</span>Model Diagnostics</a></span></li><li><span><a href="#Model-Validation" data-toc-modified-id="Model-Validation-5.1.3.3"><span class="toc-item-num">5.1.3.3&nbsp;&nbsp;</span>Model Validation</a></span></li></ul></li><li><span><a href="#Train/validation-conclusions" data-toc-modified-id="Train/validation-conclusions-5.1.4"><span class="toc-item-num">5.1.4&nbsp;&nbsp;</span>Train/validation conclusions</a></span></li></ul></li><li><span><a href="#Final-Models" data-toc-modified-id="Final-Models-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Final Models</a></span><ul class="toc-item"><li><span><a href="#Brand-1" data-toc-modified-id="Brand-1-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Brand 1</a></span></li><li><span><a href="#Brand-2" data-toc-modified-id="Brand-2-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Brand 2</a></span></li><li><span><a href="#Brand-3" data-toc-modified-id="Brand-3-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Brand 3</a></span></li></ul></li></ul></li><li><span><a href="#Discussion-and-Management-Implication" data-toc-modified-id="Discussion-and-Management-Implication-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Discussion and Management Implication</a></span></li><li><span><a href="#Latex-Outputs-For-Report" data-toc-modified-id="Latex-Outputs-For-Report-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Latex Outputs For Report</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
import re
import pandas as pd
import numpy as np
import scipy

import calendar

import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.nonparametric.smoothers_lowess import  lowess

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from IPython.core.display import display, Markdown, Latex, HTML

import warnings; warnings.simplefilter('ignore')

# %%
#visualisation libraries
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

#matplotlib styling
plt.rcParams['font.family'] = 'serif'

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# **Custom Python Files**
#
# Please see `constants.py` and `utils.py` for custom functions.
# All constants from `constants.py` are in upper case

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#custom python files
from utils import *
from constants import *

# %% [markdown]
# # Load Data

# %% [markdown]
# The data covers weekly sales, price, display and feature information for three brands of beer for the supermarket chain Dominicks over 227 weeks.
#
# Retailer margin and wholesale price for each brand is also included.

# %%
data = pd.read_excel(f"{DATA_FOLDER}/01_raw/beer_data_chicago_Dominicks.xlsx", index_col='Week ')

# %% [markdown]
# **Add unit sales**
#
# The SCAN\*PRO model estimates *unit* sales rather than \\$ sales. Therefore we need to create a new feature which is the estimated unit sales of each beer brand. This can be created by dividing sales ($) (SALESBRAND\*) by the average price in the week (PRICEBRAND\*) and rounding to the nearest integer.

# %%
brand_sales_cols = ['SALESBRAND1','SALESBRAND2','SALESBRAND3']
brand_price_cols = ['PRICEBRAND1','PRICEBRAND2','PRICEBRAND3']


#calculate units (round to nearest integer)
for s,p in zip(brand_sales_cols,brand_price_cols):
    data[f"UNITSBRAND{s[-1]}"] = (data[s]/data[p]).astype(int)

# %% [markdown]
# **Add timeseries dates**
#
# The data is a time series. Currently the weeks are expressed as a incrementing series from 1 to 227. In the [literature](https://pubsonline.informs.org/doi/10.1287/mnsc.1040.0225) it is stated that the dataset begins in June 1989. It will be assumed that the data starts from week 1 (starting on a Sunday) of June 1989. Therefore the index will be converted to the actual dates and new column will be added to the dataset which describes the month of the year (this will be important for incorporating seasonality into the model).

# %%
# convert index to datetime
data.index = pd.date_range(start='1989/06/01', periods=len(data), freq='W')
data['month'] = data.index.month_name()

# %% [markdown]
# **Final data**

# %%
#assert no missing data
assert data.isnull().sum().sum() == 0

print(f"There are {data.shape[0]} datapoints")
data.head()
# Out:
# There are 227 datapoints
#             CategorySales  PRICEBRAND1  PRICEBRAND2  PRICEBRAND3  \
# 1989-06-04   62929.477667     5.005623     4.562936     4.293051
# 1989-06-11   70907.531666     4.759082     4.666338     4.342844
# 1989-06-18   67031.204999     4.630858     4.770684     4.913317
# 1989-06-25   83289.667166     4.222040     4.266464     4.934866
# 1989-07-02  122057.548834     4.105199     4.103394     4.905153
#
#             display_brand1  display_brand2  display_brand3  FEATUREBRAND1  \
# 1989-06-04           0.000           0.124           0.092            0.0
# 1989-06-11           0.234           0.075           0.089            0.0
# 1989-06-18           0.256           0.119           0.044            0.0
# 1989-06-25           0.105           0.120           0.016            0.0
# 1989-07-02           0.180           0.092           0.000            0.0
#
#             FEATUREBRAND2  FEATUREBRAND3  RETAILERMARGINBRAND1  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Dataset characteristics

# %% [markdown]
# The main features of the dataset available for modelling include ([Srinivasan et. al, 2002](https://pubsonline.informs.org/doi/10.1287/mnsc.1040.0225)):
# - PRICEBRAND*: the average price of the beer brand during the week
# - display_brand*: the percentage of stock keeping units which were put on display
# - FEATUREBRAND*: the percentage of stock keeping units which were 'featured' during the week
# - REATAILERMARGINBRAND*: the percentage profit (margin) the retailer made on the sale of each product
# - SALESBRAND*: the sales in dollars (\\$)
# - WHOLESALEPRICE*: the wholesale price of the product
# - UNITSBRAND*: the number of units sold in each week

# %%
#descriptive statistics for the dataframe
data.describe().T
# Out:
#                       count          mean           std           min  \
# CategorySales         227.0  62567.408851  18223.926584  37429.139167
# PRICEBRAND1           227.0      4.756340      0.243022      4.104838
# PRICEBRAND2           227.0      4.536854      0.329527      3.221186
# PRICEBRAND3           227.0      4.644886      0.258895      3.882713
# display_brand1        227.0      0.182921      0.091583      0.000000
# display_brand2        227.0      0.119185      0.034654      0.029000
# display_brand3        227.0      0.135416      0.092158      0.000000
# FEATUREBRAND1         227.0      0.007533      0.022433      0.000000
# FEATUREBRAND2         227.0      0.002048      0.004879      0.000000
# FEATUREBRAND3         227.0      0.001238      0.009878      0.000000
# RETAILERMARGINBRAND1  227.0      0.083540      0.056322     -0.149657
# RETAILERMARGINBRAND2  227.0      0.084683      0.044466     -0.108038
# ...

# %% [markdown]
# ## Dataset features

# %%
cols = data.columns
brand_units_cols = get_cols(r"UNITS", cols)
brand_price_cols = get_cols(r"^PRICE", cols)
brand_display_cols = get_cols(r"display", cols)
brand_feature_cols = get_cols(r"FEATURE", cols)
brand_wholesale_cols = get_cols(r"WHOLESALE", cols)


fig, axs = plt.subplots(nrows=2,ncols=2,figsize=(15,10))

axs[0][0] = plot_cols(data, brand_units_cols, axs[0][0], "Unit sales by brand", "Units")
axs[0][1] = plot_cols(data, brand_price_cols, axs[0][1], "Brand price trend", "Price $")
axs[1][0] = plot_cols(data, brand_display_cols, axs[1][0], "Brand display", "% of SKUs")
axs[1][1] = plot_cols(data, brand_feature_cols, axs[1][1], "Brand feature", "% of SKUs")


plt.subplots_adjust(hspace=0.3)

plt.savefig(f"{VISUALISATION_FOLDER}/eda_plots.png")
plt.show()

# %% [markdown]
# Brand 1 and 2 are the most popular beer brands with similar weekly unit sales and high variation from week to week. Whereas brand 3 has a much more consistent but lower sales volume. The retail sales price of each brand is similar and hovers between approximately \\$4 and \\$5. At least a certain percentage of each brand is on 'display' each week with brand 1 generally having the largest percentage of stock keeping units on display. Beer brands are 'featured' much less frequently.
#
# The SCAN\*PRO model is sensitive to bias in the estimated parameters if the variables are endogenous. For example, the price coefficient may be biased if store managers set their prices based on the level of sales of the product. If this is the case an instrumental variable approach can be taken using wholesale prices instead which are not controlled by the manager.
#
# The potential endogeneity problem will be investigated later in the analysis if required.

# %%
fig, ax = plt.subplots(nrows=1, figsize=(7,5))
plot_cols(data, brand_wholesale_cols, ax, title='Brand Wholesale Prices',ylabel='$')
plt.show()

# %% [markdown]
# ## Seasonality

# %%
brand1_seasonality = seasonal_decompose(data['UNITSBRAND1'], model='additive', period=52)
brand2_seasonality = seasonal_decompose(data['UNITSBRAND2'], model='additive', period=52)
brand3_seasonality = seasonal_decompose(data['UNITSBRAND3'], model='additive', period=52)

seasonal_results = [brand1_seasonality,brand2_seasonality,brand3_seasonality]


fig, axs = plt.subplots(3,1, figsize=(15,10))

for i, (result, ax) in enumerate(zip(seasonal_results,axs)):
    result.seasonal.plot(ax=ax, color=BRAND_COLORS[i])
    ax.set_title(f"Brand {i+1}")
    ax.set_ylabel("Seasonal component")

plt.suptitle("Seasonal component of beer unit sales", y=0.98, fontsize=22)

plt.subplots_adjust(hspace=0.6)
plt.savefig(f"{VISUALISATION_FOLDER}/seasonal_plots.png")
plt.show()

# %% [markdown]
# All three brands exhibit a significant seasonal impact on unit sales. This will need to be incorporated into the regression model.
#
# Sales of beer are much higher in the summer months (May-September) compared to the winter months. There also appears to be a small peak in November/December each year probably as a result of the Thanksgiving/Christmas holiday season.

# %% [markdown]
# # Data Preparation
#
# Cleaning and transforming the data for modelling.
#
# The SCAN\*PRO model is a multiplicative model, however, the parameters can be log transformed to create a linear model which is easier to estimate.
#
# Following the EDA, a series of new/transformed features will be added to the dataset to be used in the regression model. Subsets of these features will be chosen for the final regression model:
# 1. A log transformation will be applied to each column so the model can be expressed as a linear function. Note that due to the presence of zero values, a log(x+1) transformation will be applied.
# 2. Seasonal dummy variables will be added to account for the seasonality in the unit sales
# 3. The 'FEATUREDBRAND*' columns will be converted into a binary variable as most of the values are zero

# %% [markdown]
# ## Log Transformation

# %%
#apply log transofation to all numeric columns
log_transform = data.select_dtypes(exclude='object').apply(lambda x: np.log(x+1),axis=1)

#add 'log_' prefix to column names
log_transform = log_transform.add_prefix('log_')

#add log_ columns to the dataset
data[log_transform.columns] = log_transform

# %% [markdown]
# ## Seasonal Dummy Variables

# %%
#drop one dummy variable
data = pd.get_dummies(data, columns=['month'],drop_first=True, prefix='', prefix_sep='')

# %% [markdown]
# ## Binary Variables

# %%
binary_col_names = ['binary_' + col for col in brand_feature_cols]
binary_col_names
# Out:
# ['binary_FEATUREBRAND1', 'binary_FEATUREBRAND2', 'binary_FEATUREBRAND3']

# %%
data[binary_col_names] = data[brand_feature_cols].applymap(lambda x: 1 if x>0.01 else 0)

# %%
data.head(10)
# Out:
#             CategorySales  PRICEBRAND1  PRICEBRAND2  PRICEBRAND3  \
# 1989-06-04   62929.477667     5.005623     4.562936     4.293051
# 1989-06-11   70907.531666     4.759082     4.666338     4.342844
# 1989-06-18   67031.204999     4.630858     4.770684     4.913317
# 1989-06-25   83289.667166     4.222040     4.266464     4.934866
# 1989-07-02  122057.548834     4.105199     4.103394     4.905153
# 1989-07-09   79422.435333     4.630080     4.727706     4.437782
# 1989-07-16   60767.206834     5.010509     4.363861     4.920926
# 1989-07-23   74765.591500     4.483190     4.349144     4.970656
# 1989-07-30   73463.889999     4.387120     4.439494     4.847055
# 1989-08-06   66375.395333     4.396502     4.438518     4.847157
#
#             display_brand1  display_brand2  display_brand3  FEATUREBRAND1  \
# 1989-06-04           0.000           0.124           0.092            0.0
# 1989-06-11           0.234           0.075           0.089            0.0
# ...

# %% [markdown]
# ## Train/test Split

# %%
TRAIN_SIZE = 0.8
SEED = 42

# %%
train, test = train_test_split(data, train_size=0.75, shuffle=True, random_state=SEED)

# %% [markdown]
# ## Save Processed Data

# %%
data.to_csv(f"{DATA_FOLDER}/02_processed/all_data.csv")
train.to_csv(f"{DATA_FOLDER}/02_processed/train.csv")
test.to_csv(f"{DATA_FOLDER}/02_processed/test.csv")

# %% [markdown]
# # SCAN\*PRO Regression
#
# A regression model for each brand will be created to estimate the (log) unit sales the beer brand.

# %% [markdown]
# ## Train/validation
#
# The target for each model will be the log_unit sales of the brand in question. The features for the model will include:
# - Seasonal dummy variables
# - 'FEATURED' as binary variable
# - log price
# - log display
#
# The models will be first estimated using a training set and validated on a test set to indicate whether the SCAN\*PRO model is a good fit for the data.

# %%
#create a list of months
months = [calendar.month_name[i] for i in range(1,13)]

seasonal_cols = [col for col in data.columns if col in months]
binary_feature_cols = get_cols('^binary', data.columns)
log_display_cols = get_cols('^log_display', data.columns)
log_price_cols = get_cols('^log_PRICE', data.columns)



model1_features = (
    log_price_cols + 
    log_display_cols + 
    binary_feature_cols + 
    seasonal_cols
)

# %%
#create empty dictionary to save model results to
model_validation_results = {}

# %% [markdown]
# ### Brand 1

# %% [markdown]
# #### Model Estimation

# %%
#use estimate_ols function from `utils.py`, this will save the output to the '../results/' folder
brand1_model1_train = estimate_ols(target_col='log_UNITSBRAND1',
                                   feature_cols=model1_features,
                                   df=train,
                                   model_name='brand1_model1_train')

#save result to results dictionary
model_validation_results['brand1_model1'] = {}
model_validation_results['brand1_model1']['r2'] = brand1_model1_train.rsquared

print(brand1_model1_train.summary())
print("\n"*2)
plot_coef_conf_int(brand1_model1_train)
plt.savefig(f"{VISUALISATION_FOLDER}/brand1_model1_train_significance.png")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        log_UNITSBRAND1   R-squared:                       0.792
# Model:                            OLS   Adj. R-squared:                  0.764
# Method:                 Least Squares   F-statistic:                     28.41
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           6.37e-41
# Time:                        20:01:39   Log-Likelihood:                 69.627
# No. Observations:                 170   AIC:                            -97.25
# Df Residuals:                     149   BIC:                            -31.40
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   18.8241      1.273     14.788      0.000      16.309      21.339
# ...

# %% [markdown]
# The model provides a relatively good fit for the data with an $R^{2}$ of 0.792 indicating that 79% of the variation in the unit sales of brand 1 is captured by the model.

# %% [markdown]
# #### Model Diagnostics
#
# Evaluate the diagnostic plots for the regression models to check OLS assumptions

# %%
plot_diagnostics(brand1_model1_train, "Brand 1 (train)")
plt.savefig(f"{VISUALISATION_FOLDER}/brand1_model1_train_diagnostics.png")
plt.show()

# %% [markdown]
# The residuals appear to be randomly and normally distributed.

# %% [markdown]
# #### Model Validation

# %%
preds = brand1_model1_train.predict(sm.add_constant(test[model1_features]))

rmse = mean_squared_error(test['log_UNITSBRAND1'],preds)**0.5
model_validation_results['brand1_model1']['rmse'] = rmse

print(f"RMSE = {round(rmse,4)}")

plot_preds_versus_actual(preds,test['log_UNITSBRAND1'], "Brand 1 (train)")
plt.savefig(f"{VISUALISATION_FOLDER}/brand1_model1_train_val.png")
plt.show()
# Out:
# RMSE = 0.1659

# %% [markdown]
# ### Brand 2

# %% [markdown]
# #### Model Estimation

# %%
#use estimate_ols function from `utils.py`, this will save the output to the '../results/' folder
brand2_model1_train = estimate_ols(target_col='log_UNITSBRAND2',
                                   feature_cols=model1_features,
                                   df=train,
                                   model_name='brand2_model1_train')

#save result to results dictionary
model_validation_results['brand2_model1'] = {}
model_validation_results['brand2_model1']['r2'] = brand2_model1_train.rsquared

print(brand2_model1_train.summary())
print("\n"*2)
plot_coef_conf_int(brand2_model1_train)
plt.savefig(f"{VISUALISATION_FOLDER}/brand2_model1_train_significance.png")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        log_UNITSBRAND2   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.788
# Method:                 Least Squares   F-statistic:                     32.35
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           3.38e-44
# Time:                        20:01:43   Log-Likelihood:                 90.869
# No. Observations:                 170   AIC:                            -139.7
# Df Residuals:                     149   BIC:                            -73.89
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   16.5339      1.123     14.718      0.000      14.314      18.754
# ...

# %% [markdown]
# #### Model Diagnostics

# %%
plot_diagnostics(brand2_model1_train, "Brand 2 (train)")
plt.savefig(f"{VISUALISATION_FOLDER}/brand2_model1_train_diagnostics.png")
plt.show()

# %% [markdown]
# #### Model Validation

# %%
preds = brand2_model1_train.predict(sm.add_constant(test[model1_features]))

rmse = mean_squared_error(test['log_UNITSBRAND2'],preds)**0.5
model_validation_results['brand2_model1']['rmse'] = rmse

print(f"RMSE = {round(rmse,4)}")

plot_preds_versus_actual(preds,test['log_UNITSBRAND2'], "Brand 2 (train)")
plt.savefig(f"{VISUALISATION_FOLDER}/brand2_model1_train_val.png")
plt.show()
# Out:
# RMSE = 0.172

# %% [markdown]
# ### Brand 3

# %% [markdown]
# #### Model Estimation

# %%
#use estimate_ols function from `utils.py`, this will save the output to the '../results/' folder
brand3_model1_train = estimate_ols(target_col='log_UNITSBRAND3',
                                   feature_cols=model1_features,
                                   df=train,
                                   model_name='brand3_model1_train')

#save result to results dictionary
model_validation_results['brand3_model1'] = {}
model_validation_results['brand3_model1']['r2'] = brand3_model1_train.rsquared

print(brand3_model1_train.summary())
print("\n"*2)
plot_coef_conf_int(brand3_model1_train)
plt.savefig(f"{VISUALISATION_FOLDER}/brand3_model1_train_significance.png")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        log_UNITSBRAND3   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.789
# Method:                 Least Squares   F-statistic:                     32.60
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           2.14e-44
# Time:                        20:01:46   Log-Likelihood:                 81.306
# No. Observations:                 170   AIC:                            -120.6
# Df Residuals:                     149   BIC:                            -54.76
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   14.9059      1.188     12.543      0.000      12.558      17.254
# ...

# %% [markdown]
# #### Model Diagnostics

# %%
plot_diagnostics(brand3_model1_train, "Brand 3 (train)")
plt.savefig(f"{VISUALISATION_FOLDER}/brand3_model1_train_diagnostics.png")
plt.show()

# %% [markdown]
# #### Model Validation

# %%
preds = brand3_model1_train.predict(sm.add_constant(test[model1_features]))

rmse = mean_squared_error(test['log_UNITSBRAND3'],preds)**0.5
model_validation_results['brand3_model1']['rmse'] = rmse

print(f"RMSE = {round(rmse,4)}")

plot_preds_versus_actual(preds,test['log_UNITSBRAND3'], "Brand 3 (train)")
plt.savefig(f"{VISUALISATION_FOLDER}/brand3_model1_train_val.png")
plt.show()
# Out:
# RMSE = 0.1774

# %% [markdown]
# ### Train/validation conclusions

# %%
model_validation_results
# Out:
# {'brand1_model1': {'r2': 0.7922329663848333, 'rmse': 0.16593977008800298},
#  'brand2_model1': {'r2': 0.8128036918712811, 'rmse': 0.1720202024583431},
#  'brand3_model1': {'r2': 0.8139893257702171, 'rmse': 0.17737488512589342}}

# %% [markdown]
# All three models show a good fit for the data ($R^2$ ~ 0.8), diagnostic plots which confirm regression normality and heteroskedasticity assumptions, and give reasonable predictions on the unseen test data sets. Therefore, we can conclude that the model with seasonal dummy variables and binary featured variables is an appropriate and good model to estimate units sales of beer for each brand.

# %%
validation_results_df = pd.DataFrame(model_validation_results).T
validation_results_df.index = ['Brand 1','Brand 2', 'Brand 3']
Latex(validation_results_df.to_latex())
# Out:
# \begin{tabular}{lrr}
# \toprule
# {} &        r2 &      rmse \\
# \midrule
# Brand 1 &  0.792233 &  0.165940 \\
# Brand 2 &  0.812804 &  0.172020 \\
# Brand 3 &  0.813989 &  0.177375 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# ## Final Models

# %% [markdown]
# Before interpreting the coefficients of the models, each regression model will be retrained on all the data.

# %% [markdown]
# **Retrain on all data**

# %%
brand1_modelfinal = estimate_ols(target_col='log_UNITSBRAND1',
                                 feature_cols=model1_features,
                                 df=data, #use all data
                                 model_name='brand1_modelfinal')

brand2_modelfinal = estimate_ols(target_col='log_UNITSBRAND2',
                                 feature_cols=model1_features,
                                 df=data, #use all data
                                 model_name='brand2_modelfinal')

brand3_modelfinal = estimate_ols(target_col='log_UNITSBRAND3',
                                 feature_cols=model1_features,
                                 df=data, #use all data
                                 model_name='brand3_modelfinal')

# %%
final_model_results = {}

# %% [markdown]
# ### Brand 1

# %%
#save result to results dictionary
final_model_results['brand1'] = {}
final_model_results['brand1']['r2'] = brand1_modelfinal.rsquared

print(brand1_modelfinal.summary())
print("\n"*2)
plot_coef_conf_int(brand1_modelfinal)
plt.savefig(f"{VISUALISATION_FOLDER}/brand1_modelfinal_significance.png")
plt.show()

plot_diagnostics(brand1_modelfinal, "Brand 1")
plt.savefig(f"{VISUALISATION_FOLDER}/brand1_modelfinal_diagnostics.png")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        log_UNITSBRAND1   R-squared:                       0.777
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     35.96
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           3.77e-56
# Time:                        20:01:51   Log-Likelihood:                 94.246
# No. Observations:                 227   AIC:                            -146.5
# Df Residuals:                     206   BIC:                            -74.57
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   18.8007      1.033     18.206      0.000      16.765      20.837
# ...

# %% [markdown]
# **Price**
#
# As expected the biggest effect on unit sales is the price of brand 1's product. As the price and target variable (unit sales) are both in log form, the coefficient of `log_PRICEBRAND1` can be interpreted as meaning that if the price of brand 1 is reduced by 1%, unit sales will increase by 4.87%. Interestingly, brand 1's unit sales are also increased if the price of brand 3 is reduced, however, this is to a much lesser extent. If brand 2's price is decreased by 1%, unit sales of brand 1 are reduced by 1.40%. This makes sense as according to the unit sale plots of brand 1 and 2, they are selling in approximately the same volumes and are as popular as each other, so there might be a propensity for consumers to switch brand depending on price changes.
#
# **display**
#
# Only `log_display_brand1` is statistically significant for the `display` variables. Therefore, whether brand 2 or 3 are on display has no effect on the unit sales of brand 1. The `display` variable is expressed as a percentage of stock keeping units (SKUs), therefore the coefficient of 0.67 for `log_display_brand1` can be interpreted as meaning that if the percentage of SKUs on display of brand 1 are increased by 1% (note this is not the same as an increase in SKU by 1 *percentage point*) then the unit sales can be expected to increase by 0.67%.
#
# **Feature**
#
# Only `binary_FEATUREBRAND1` is statistically significant for the `FEATURE` variables. The magnitude of the coefficient is 0.0939. As this is a *binary* variable and the target column was created using a log(x+1) transformation, the coefficient value is actually interpreted as being $e^{coefficient}$ i.e. $e^{0.0939}$ = 1.0984. This means that if the brand 1 is featured in a particular week (i.e. binary_FEATUREBRAND1 = 1), then unit sales can be expected to increase by 9.84%.

# %% [markdown]
# ### Brand 2

# %%
#save result to results dictionary
final_model_results['brand2'] = {}
final_model_results['brand2']['r2'] = brand2_modelfinal.rsquared

print(brand2_modelfinal.summary())
print("\n"*2)
plot_coef_conf_int(brand2_modelfinal)
plt.savefig(f"{VISUALISATION_FOLDER}/brand2_modelfinal_significance.png")
plt.show()

plot_diagnostics(brand2_modelfinal, "Brand 2")
plt.savefig(f"{VISUALISATION_FOLDER}/brand2_modelfinal_diagnostics.png")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        log_UNITSBRAND2   R-squared:                       0.805
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                     42.52
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           6.01e-62
# Time:                        20:01:52   Log-Likelihood:                 111.22
# No. Observations:                 227   AIC:                            -180.4
# Df Residuals:                     206   BIC:                            -108.5
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   16.6887      0.958     17.416      0.000      14.799      18.578
# ...

# %% [markdown]
# **Price**
#
# The coefficient of `log_PRICEBRAND2` can be interpreted as meaning that if the price of brand 2 is reduced by 1%, unit sales will increase by 3.67%.
#
# **display**
#
# Only `log_display_brand2` is statistically significant for the `display` variables. Therefore, whether brand 2 or 3 are on display has no effect on the unit sales of brand 1. The `display` variable is expressed as a percentage of stock keeping units (SKUs), therefore the coefficient of 2.58 for `log_display_brand2` can be interpreted as meaning that if the percentage of SKUs on display of brand 2 are increased by 1% then the unit sales can be expected to increase by 2.58%.
#
# **Feature**
#
# None of the 'FEATURE' variables are statistically significant in the regression model for brand 2 unit sales. It would be expected that featuring brand 2 would increase its sales. The coefficient for `binary_FEATUREBRAND2` is 0.0325, however, the p value is extremely high (0.401) so we cannot reject the null hypothesis that the coefficient is 0 and there is no effect on sales when brand 2 is featured. `binary_FEATUREBRAND1` and `binary_FEATUREBRAND3` are also statistically insignificant with very high p values (0.679 and 0.747) so we can say that there is no effect on brand 2 sales if brand 1 or brand 3 are featured in that week.

# %% [markdown]
# ### Brand 3

# %%
#save result to results dictionary
final_model_results['brand3'] = {}
final_model_results['brand3']['r2'] = brand3_modelfinal.rsquared

print(brand3_modelfinal.summary())
print("\n"*2)
plot_coef_conf_int(brand3_modelfinal)
plt.savefig(f"{VISUALISATION_FOLDER}/brand3_modelfinal_significance.png")
plt.show()

plot_diagnostics(brand3_modelfinal, "Brand 3")
plt.savefig(f"{VISUALISATION_FOLDER}/brand3_modelfinal_diagnostics.png")
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        log_UNITSBRAND3   R-squared:                       0.802
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     41.69
# Date:                Sun, 12 Apr 2020   Prob (F-statistic):           2.92e-61
# Time:                        20:01:54   Log-Likelihood:                 100.73
# No. Observations:                 227   AIC:                            -159.5
# Df Residuals:                     206   BIC:                            -87.53
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   14.9740      1.004     14.920      0.000      12.995      16.953
# ...

# %% [markdown]
# **Price**
#
# The coefficient of `log_PRICEBRAND3` can be interpreted as meaning that if the price of brand 3 is reduced by 1%, unit sales will increase by 6.14%.
#
# **display**
#
# `log_display_brand3` has a coefficient of -0.4286 which is statistically significant, however, there is a relatively large error boundary which reaches an upper level of -0.017. This suggests that displaying more stock keeping units of brand 3 actually decreases the unit sales. The coefficient for `log_display_brand2` shows that if more of brand 2 is displayed unit sales of brand 3 will increase.
#
# **Feature**
#
# Once again, none of the 'FEATURE' variables are statistically significant in the regression model for brand 3 unit sales. The `binary_FEATUREBRAND3` coefficient is 0.1231 with a p value of 0.237. Even though the confidence in this coefficient is low and we cannot reject the null hypothesis, it would imply that if brand 3 is featured it would increase unit sales by 13.1% ($e^{0.1231)$ = 1.1310).

# %% [markdown]
# # Discussion and Management Implication

# %% [markdown]
#     b

# %%
brand_params = {}

for i, model in zip([1,2,3],[brand1_modelfinal,brand2_modelfinal,brand3_modelfinal]):
    brand_params[f'brand{i}'] = {}
    brand_params[f'brand{i}']['log_PRICE'] = model.params[f'log_PRICEBRAND{i}']
    brand_params[f'brand{i}']['log_display'] = model.params[f'log_display_brand{i}']
    brand_params[f'brand{i}']['binary_FEATURE'] = np.exp(model.params[f'binary_FEATUREBRAND{i}'])

# %%
pd.DataFrame(brand_params)
# Out:
#                   brand1    brand2    brand3
# binary_FEATURE  1.098416  1.033053  1.131044
# log_PRICE      -4.873988 -3.682217 -6.140676
# log_display     0.673647  2.582541 -0.428605

# %%
brand1_modelfinal.params['log_PRICEBRAND1']
brand1_modelfinal.params['log_display_brand1']
# Out:
# 0.6736468162938422

# %% [markdown]
# ----------
#
# # Latex Outputs For Report
#
# Copy and paste output into the report

# %%
display(HTML("<h3>Brand 1</h3>"))
Latex(brand1_modelfinal.summary().as_latex())
# Out:
# <h3>Brand 1</h3>
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}        & log\_UNITSBRAND1 & \textbf{  R-squared:         } &     0.777   \\
# \textbf{Model:}                &       OLS        & \textbf{  Adj. R-squared:    } &     0.756   \\
# \textbf{Method:}               &  Least Squares   & \textbf{  F-statistic:       } &     35.96   \\
# \textbf{Date:}                 & Sun, 12 Apr 2020 & \textbf{  Prob (F-statistic):} &  3.77e-56   \\
# \textbf{Time:}                 &     20:01:56     & \textbf{  Log-Likelihood:    } &    94.246   \\
# \textbf{No. Observations:}     &         227      & \textbf{  AIC:               } &    -146.5   \\
# \textbf{Df Residuals:}         &         206      & \textbf{  BIC:               } &    -74.57   \\
# \textbf{Df Model:}             &          20      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
# ...

# %%
display(HTML("<h3>Brand 2</h3>"))
Latex(brand2_modelfinal.summary().as_latex())
# Out:
# <h3>Brand 2</h3>
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}        & log\_UNITSBRAND2 & \textbf{  R-squared:         } &     0.805   \\
# \textbf{Model:}                &       OLS        & \textbf{  Adj. R-squared:    } &     0.786   \\
# \textbf{Method:}               &  Least Squares   & \textbf{  F-statistic:       } &     42.52   \\
# \textbf{Date:}                 & Sun, 12 Apr 2020 & \textbf{  Prob (F-statistic):} &  6.01e-62   \\
# \textbf{Time:}                 &     20:01:57     & \textbf{  Log-Likelihood:    } &    111.22   \\
# \textbf{No. Observations:}     &         227      & \textbf{  AIC:               } &    -180.4   \\
# \textbf{Df Residuals:}         &         206      & \textbf{  BIC:               } &    -108.5   \\
# \textbf{Df Model:}             &          20      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
# ...

# %%
display(HTML("<h3>Brand 3</h3>"))
Latex(brand3_modelfinal.summary().as_latex())
# Out:
# <h3>Brand 3</h3>
# \begin{center}
# \begin{tabular}{lclc}
# \toprule
# \textbf{Dep. Variable:}        & log\_UNITSBRAND3 & \textbf{  R-squared:         } &     0.802   \\
# \textbf{Model:}                &       OLS        & \textbf{  Adj. R-squared:    } &     0.783   \\
# \textbf{Method:}               &  Least Squares   & \textbf{  F-statistic:       } &     41.69   \\
# \textbf{Date:}                 & Sun, 12 Apr 2020 & \textbf{  Prob (F-statistic):} &  2.92e-61   \\
# \textbf{Time:}                 &     20:01:57     & \textbf{  Log-Likelihood:    } &    100.73   \\
# \textbf{No. Observations:}     &         227      & \textbf{  AIC:               } &    -159.5   \\
# \textbf{Df Residuals:}         &         206      & \textbf{  BIC:               } &    -87.53   \\
# \textbf{Df Model:}             &          20      & \textbf{                     } &             \\
# \bottomrule
# \end{tabular}
# \begin{tabular}{lcccccc}
# ...
