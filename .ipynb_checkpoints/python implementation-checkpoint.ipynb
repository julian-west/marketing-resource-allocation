# %% [markdown]
# <p style="font-size:29px"><strong>Retail Marketing Individual Assignment</strong></p>
#
# Analysis notebook.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Load-Data" data-toc-modified-id="Load-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Load Data</a></span></li><li><span><a href="#EDA" data-toc-modified-id="EDA-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Dataset-characteristics" data-toc-modified-id="Dataset-characteristics-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Dataset characteristics</a></span></li><li><span><a href="#Dataset-features" data-toc-modified-id="Dataset-features-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Dataset features</a></span></li><li><span><a href="#Seasonality" data-toc-modified-id="Seasonality-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Seasonality</a></span></li></ul></li><li><span><a href="#Data-Preparation" data-toc-modified-id="Data-Preparation-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Preparation</a></span><ul class="toc-item"><li><span><a href="#Log-Transformation" data-toc-modified-id="Log-Transformation-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Log Transformation</a></span></li><li><span><a href="#Seasonal-Dummy-Variables" data-toc-modified-id="Seasonal-Dummy-Variables-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Seasonal Dummy Variables</a></span></li><li><span><a href="#Binary-Variables" data-toc-modified-id="Binary-Variables-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Binary Variables</a></span></li><li><span><a href="#Train/test-Split" data-toc-modified-id="Train/test-Split-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Train/test Split</a></span></li></ul></li><li><span><a href="#SCAN*PRO-Regression" data-toc-modified-id="SCAN*PRO-Regression-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>SCAN*PRO Regression</a></span></li><li><span><a href="#Retrain-Models-on-all-data" data-toc-modified-id="Retrain-Models-on-all-data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Retrain Models on all data</a></span></li><li><span><a href="#Latex-Outputs-For-Report" data-toc-modified-id="Latex-Outputs-For-Report-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Latex Outputs For Report</a></span></li></ul></div>

# %% [markdown]
# # Imports

# %%
import re
import pandas as pd
import numpy as np

import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose


from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', 500)

# %%
#visualisation libraries
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

#matplotlib styling
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False

plt.rcParams['font.family'] = 'serif'

# %% [markdown]
# **Constants**

# %%
VISUALISATION_FOLDER = "./report/visualisations"
BRAND_COLORS = ["#00AFBB", "#E7B800", "#ff0000"]

# %% [markdown]
# # Load Data

# %% [markdown]
# The data covers weekly sales, price, display and feature information for three brands of beer for the supermarket chain Dominicks over 227 weeks.
#
# Retailer margin and wholesale price for each brand is also included.

# %%
data = pd.read_excel("./data/beer_data_chicago_Dominicks.xlsx", index_col='Week ')

# %% [markdown]
# **Add unit sales**
#
# The SCAN\*PRO model estimates *unit* sales rather than \\$ sales. Therefore we need to create a new feature which is the estimated unit sales of each beer brand. This can be created by dividing sales ($) (SALESBRAND\*) by the average price in the week (PRICEBRAND\*) and rounding to the nearest integer.

# %%
brand_sales_cols = ['SALESBRAND1','SALESBRAND2','SALESBRAND3']
brand_price_cols = ['PRICEBRAND1','PRICEBRAND2','PRICEBRAND3']


#calculate units (round to nearest integer)
for s,p in zip(brand_sales_cols,brand_price_cols):
    data[f"UNITSBRAND{s[-1]}"] = (data[s]/data[p]).astype(int)

# %% [markdown]
# **Add timeseries dates**
#
# The data is a time series. Currently the weeks are expressed as a incrementing series from 1 to 227. In the [literature](https://pubsonline.informs.org/doi/10.1287/mnsc.1040.0225) it is stated that the dataset begins in September 1989. It will be assumed that the data starts from week 1 (starting on a Sunday) of September 1989. Therefore the index will be converted to the actual dates and new column will be added to the dataset which describes the month of the year (this will be important for incorporating seasonality into the model).

# %%
# convert index to datetime
data.index = pd.date_range(start='1989/09/01', periods=len(data), freq='W')
data['month'] = data.index.month_name()

# %% [markdown]
# **Final data**

# %%
#assert no missing data
assert data.isnull().sum().sum() == 0

print(f"There are {data.shape[0]} datapoints")
data.head()
# Out:
# There are 227 datapoints
#             CategorySales  PRICEBRAND1  PRICEBRAND2  PRICEBRAND3  \
# 1989-09-03   62929.477667     5.005623     4.562936     4.293051
# 1989-09-10   70907.531666     4.759082     4.666338     4.342844
# 1989-09-17   67031.204999     4.630858     4.770684     4.913317
# 1989-09-24   83289.667166     4.222040     4.266464     4.934866
# 1989-10-01  122057.548834     4.105199     4.103394     4.905153
#
#             display_brand1  display_brand2  display_brand3  FEATUREBRAND1  \
# 1989-09-03           0.000           0.124           0.092            0.0
# 1989-09-10           0.234           0.075           0.089            0.0
# 1989-09-17           0.256           0.119           0.044            0.0
# 1989-09-24           0.105           0.120           0.016            0.0
# 1989-10-01           0.180           0.092           0.000            0.0
#
#             FEATUREBRAND2  FEATUREBRAND3  RETAILERMARGINBRAND1  \
# 1989-09-03            0.0            0.0              0.120878
# 1989-09-10            0.0            0.0              0.135090
# 1989-09-17            0.0            0.0              0.119915
# 1989-09-24            0.0            0.0              0.129831
# 1989-10-01            0.0            0.0              0.133630
#
#             RETAILERMARGINBRAND2  RETAILERMARGINBRAND3   SALESBRAND1  \
# 1989-09-03              0.136304              0.156036  24321.600000
# 1989-09-10              0.089354              0.157650  33005.983333
# 1989-09-17              0.081313              0.123846  34129.983333
# 1989-09-24              0.166255              0.131854  41453.750000
# 1989-10-01              0.124810              0.130308  67620.016667
#
#              SALESBRAND2   SALESBRAND3  WHOLESALEPRICE1  WHOLESALEPRICE2  \
# 1989-09-03  27790.157667  10817.720000         4.011377         4.323338
# 1989-09-10  26466.924333  11434.624000         4.035964         4.333838
# 1989-09-17  26000.576333   6900.645333         4.198608         4.254309
# 1989-09-24  35708.431833   6127.485333         3.712543         3.520105
# 1989-10-01  46842.793500   7594.738667         3.555056         3.592828
#
#             WHOLESALEPRICE3  UNITSBRAND1  UNITSBRAND2  UNITSBRAND3      month
# 1989-09-03         3.623182         4858         6090         2519  September
# 1989-09-10         3.658193         6935         5671         2632  September
# 1989-09-17         4.304820         7370         5450         1404  September
# 1989-09-24         4.284186         9818         8369         1241  September
# 1989-10-01         4.265970        16471        11415         1548    October

# %% [markdown]
# # EDA

# %%
def get_cols(regex_pat, columns=data.columns):
    return [col for col in columns if re.match(regex_pat,col)]

def plot_cols(ax, cols, title, ylabel, xlabel=None, data=data):
    data[cols].plot(color=BRAND_COLORS, ax=ax)
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    
    ax.yaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{x:,.0f}'))
    
    return ax

# %% [markdown]
# ## Dataset characteristics

# %% [markdown]
# The main features of the dataset available for modelling include ([Srinivasan et. al, 2002](https://pubsonline.informs.org/doi/10.1287/mnsc.1040.0225)):
# - PRICEBRAND*: the average price of the beer brand during the week
# - display_brand*: the percentage of stock keeping units which were put on display
# - FEATUREBRAND*: the percentage of stock keeping units which were 'featured' during the week
# - REATAILERMARGINBRAND*: the percentage profit (margin) the retailer made on the sale of each product
# UNITSBRAND2            4548.500000   5359.000000   6733.500000   25698.000000
# UNITSBRAND3            1124.500000   1500.000000   1845.000000    5222.000000

# %% [markdown]
# ## Dataset features

# %%
brand_units_cols = get_cols(r"UNITS")
brand_price_cols = get_cols(r"^PRICE")
brand_display_cols = get_cols(r"display")
brand_feature_cols = get_cols(r"FEATURE")
brand_wholesale_cols = get_cols(r"WHOLESALE")


fig, axs = plt.subplots(nrows=2,ncols=2,figsize=(15,10))

axs[0][0] = plot_cols(axs[0][0],brand_units_cols, "Unit sales by brand", "Units")
axs[0][1] = plot_cols(axs[0][1],brand_price_cols, "Brand price trend", "Price $")
axs[1][0] = plot_cols(axs[1][0],brand_display_cols, "Brand display", "% of SKUs")
axs[1][1] = plot_cols(axs[1][1],brand_feature_cols, "Brand feature", "% of SKUs")


plt.subplots_adjust(hspace=0.3)

plt.savefig(f"{VISUALISATION_FOLDER}/eda_plots.png")
plt.show()

# %% [markdown]
# Brand 1 and 2 are the most popular beer brands with similar weekly unit sales and high variation from week to week. Whereas brand 3 has a much more consistent but lower sales volume. The retail sales price of each brand is similar and hovers between qpproximately \\$4 and \\$5. At least a certain percentage of each brand is on 'display' each week with brand 1 generally having the largest percentage of stock keeping units on display. Beer brands are 'featured' much less frequently.
#
# The SCAN\*PRO model is sensitive to bias in the estimated parameters if the variables are endogenous. For example, the price coefficient may be biased if store managers set their prices based on the level of sales of the product. If this is the case an instrumental variable approach can be taken using wholesale prices instead which are not controlled by the manager.
#
# The potential endogeneity problem will be investigated later in the analysis if required.

# %%
fig, ax = plt.subplots(nrows=1, figsize=(7,5))
plot_cols(ax=ax,cols=brand_wholesale_cols, title='Brand Wholesale Prices',ylabel='$')
plt.show()

# %% [markdown]
# ## Seasonality

# %%
brand1_seasonality = seasonal_decompose(data['UNITSBRAND1'], model='additive', period=52)
brand2_seasonality = seasonal_decompose(data['UNITSBRAND2'], model='additive', period=52)
brand3_seasonality = seasonal_decompose(data['UNITSBRAND3'], model='additive', period=52)

seasonal_results = [brand1_seasonality,brand2_seasonality,brand3_seasonality]


fig, axs = plt.subplots(3,1, figsize=(15,10))

for i, (result, ax) in enumerate(zip(seasonal_results,axs)):
    result.seasonal.plot(ax=ax, color=BRAND_COLORS[i])
    ax.set_title(f"Brand {i+1}")
    ax.set_ylabel("Seasonal component")

plt.suptitle("Seasonal component of beer unit sales", y=0.98, fontsize=22)

plt.subplots_adjust(hspace=0.6)
plt.savefig(f"{VISUALISATION_FOLDER}/seasonal_plots.png")
plt.show()

# %% [markdown]
# All three brands exhibit a significant seasonal impact on unit sales. This will need to be incorporated into the regression model.

# %% [markdown]
# # Data Preparation
#
# Cleaning and transforming the data for modelling.
#
# The SCAN\*PRO model is a multiplicative model, however, the parameters can be log transformed to create a linear model which is easier to estimate.
#
# Following the EDA, a series of new/transformed features will be added to the dataset to be used in the regression model. Subsets of these features will be chosen for the final regression model:
# 1. A log transformation will be applied to each column so the model can be expressed as a linear function. Note that due to the presence of zero values, a log(x+1) transformation will be applied.
# 2. Seasonal dummy variables will be added to account for the seasonality in the unit sales
# 3. The 'FEATUREDBRAND*' columns will be converted into a binary variable as most of the values are zero

# %% [markdown]
# ## Log Transformation

# %%
#apply log transofation to all numeric columns
log_transform = data.select_dtypes(exclude='object').apply(lambda x: np.log(x+1),axis=1)

#add 'log_' prefix to column names
log_transform = log_transform.add_prefix('log_')

#add log_ columns to the dataset
data[log_transform.columns] = log_transform

# %% [markdown]
# ## Seasonal Dummy Variables

# %%
#drop one dummy variable
data = pd.get_dummies(data, columns=['month'],drop_first=True, prefix='', prefix_sep='')

# %% [markdown]
# ## Binary Variables

# %%
binary_col_names = ['binary_' + col for col in brand_feature_cols]
binary_col_names
# Out:
# ['binary_FEATUREBRAND1', 'binary_FEATUREBRAND2', 'binary_FEATUREBRAND3']

# %%
data[binary_col_names] = data[brand_feature_cols].applymap(lambda x: 1 if x>0.01 else 0)

# %%
data.head(10)
# Out:
#             CategorySales  PRICEBRAND1  PRICEBRAND2  PRICEBRAND3  \
# 1989-09-03   62929.477667     5.005623     4.562936     4.293051
# 1989-09-10   70907.531666     4.759082     4.666338     4.342844
# 1989-09-17   67031.204999     4.630858     4.770684     4.913317
# 1989-09-24   83289.667166     4.222040     4.266464     4.934866
# 1989-10-01  122057.548834     4.105199     4.103394     4.905153
# 1989-10-08   79422.435333     4.630080     4.727706     4.437782
# 1989-10-15   60767.206834     5.010509     4.363861     4.920926
# 1989-10-22   74765.591500     4.483190     4.349144     4.970656
# 1989-10-29   73463.889999     4.387120     4.439494     4.847055
# 1989-11-05   66375.395333     4.396502     4.438518     4.847157
#
#             display_brand1  display_brand2  display_brand3  FEATUREBRAND1  \
# 1989-09-03           0.000           0.124           0.092            0.0
# 1989-09-10           0.234           0.075           0.089            0.0
# 1989-09-17           0.256           0.119           0.044            0.0
# 1989-09-24           0.105           0.120           0.016            0.0
# 1989-10-01           0.180           0.092           0.000            0.0
# 1989-10-08           0.141           0.082           0.059            0.0
# 1989-10-15           0.000           0.115           0.000            0.0
# 1989-10-22           0.108           0.097           0.000            0.0
# 1989-10-29           0.135           0.071           0.075            0.0
# 1989-11-05           0.159           0.029           0.045            0.0
#
#             FEATUREBRAND2  FEATUREBRAND3  RETAILERMARGINBRAND1  \
# 1989-09-03          0.000            0.0              0.120878
# 1989-09-10          0.000            0.0              0.135090
# 1989-09-17          0.000            0.0              0.119915
# 1989-09-24          0.000            0.0              0.129831
# 1989-10-01          0.000            0.0              0.133630
# 1989-10-08          0.005            0.0              0.146246
# 1989-10-15          0.000            0.0              0.117737
# 1989-10-22          0.000            0.0              0.129925
# 1989-10-29          0.000            0.0              0.132475
# 1989-11-05          0.000            0.0              0.137952
#
#             RETAILERMARGINBRAND2  RETAILERMARGINBRAND3   SALESBRAND1  \
# 1989-09-03              0.136304              0.156036  24321.600000
# 1989-10-29         9.033006         8.845633         7.104965       0
# 1989-11-05         9.010547         8.607399         7.136483       0
#
#             December  February  January  July  June  March  May  November  \
# 1989-09-03         0         0        0     0     0      0    0         0
# 1989-09-10         0         0        0     0     0      0    0         0
# 1989-09-17         0         0        0     0     0      0    0         0
# 1989-09-24         0         0        0     0     0      0    0         0
# 1989-10-01         0         0        0     0     0      0    0         0
# 1989-10-08         0         0        0     0     0      0    0         0
# 1989-10-15         0         0        0     0     0      0    0         0
# 1989-10-22         0         0        0     0     0      0    0         0
# 1989-10-29         0         0        0     0     0      0    0         0
# 1989-11-05         0         0        0     0     0      0    0         1
#
#             October  September  binary_FEATUREBRAND1  binary_FEATUREBRAND2  \
# 1989-09-03        0          1                     0                     0
# 1989-09-10        0          1                     0                     0
# 1989-09-17        0          1                     0                     0
# 1989-09-24        0          1                     0                     0
# 1989-10-01        1          0                     0                     0
# 1989-10-08        1          0                     0                     0
# 1989-10-15        1          0                     0                     0
# 1989-10-22        1          0                     0                     0
# 1989-10-29        1          0                     0                     0
# 1989-11-05        0          0                     0                     0
#
#             binary_FEATUREBRAND3
# 1989-09-03                     0
# 1989-09-10                     0
# 1989-09-17                     0
# 1989-09-24                     0
# 1989-10-01                     0
# 1989-10-08                     0
# 1989-10-15                     0
# 1989-10-22                     0
# 1989-10-29                     0
# 1989-11-05                     0

# %% [markdown]
# ## Train/test Split

# %%
TRAIN_SIZE = 0.8
SEED = 42

#NEED TO IMPLEMENT
#train_test_split(data.iloc[:, :-1], data.iloc[:, -1], shuffle=True, train_size=train_size, random_state=seed)

# %% [markdown]
# # SCAN\*PRO Regression
#
# https://towardsdatascience.com/going-from-r-to-python-linear-regression-diagnostic-plots-144d1c4aa5a

# %% [markdown]
# **Split into test and train**

# %%
def create_modelling_df(data, brand):
    """Create dataframe with transformed variables for modelling

    Args:
        data (pd.DataFrame): raw data loaded from Excel
        brand (int or None): the brand for which we are predicting sales (e.g. 1,2 or 3). If None, 
            model will use total category sales

    Returns:
        modelling_data (pd.DataFrame): dataframe for modelling with target column (log brand sales) 
            and features
    """

    # add month variable
    data['date'] = pd.date_range(start='1989/09/01', periods=len(data), freq='W')
    data['month'] = data['date'].dt.month_name()

    # create seasonal dummies (drop one month)
    seasonal_dummies = pd.get_dummies(data['month'], drop_first=True)

    # columns to log transform (sales, display and price)
    log_cols = [col for col in data.columns if re.match(
        "CategorySales|SALES|display|^PRICE|FEATURE", col)]
    # columns representing brand 'Feature'
    #feature_cols = [col for col in data.columns if 'FEATURE' in col]

    # create dataframe for modelling
    modelling_data = pd.DataFrame()

    # populate modelling dataframe
    for col in log_cols:
        # apply log transformation
        modelling_data[f"log_{col}"] = np.log(data[col]+1)

#     for col in feature_cols:
#         # make featured binary
#         modelling_data[f"binary_{col}"] = data[col].apply(lambda x: 1 if x > 0.01 else 0)
    
    #add seaonsal column
    modelling_data[seasonal_dummies.columns] = seasonal_dummies

    if brand == None:
        target_col = 'log_CategorySales'
    else:
        target_col = f'log_SALESBRAND{brand}'

    final_cols = [
        col for col in modelling_data.columns if 'SALES' not in col and 'CategorySales' not in col]

    return modelling_data[final_cols + [target_col]]


def create_train_test_split(data, train_size=0.75, seed=42):
    """Create the training and test datasets

    Randomly shuffle datapoints

    Args:
        data (pd.DataFrame): modelling data for a particular brand. The target column should be
            the final column in the dataframe
    """
    return train_test_split(data.iloc[:, :-1], data.iloc[:, -1], shuffle=True,
                            train_size=train_size, random_state=seed)

# %%
np.exp(0.1035)

# %%
brand1_df

# %% [markdown]
# **Create dataframes for each brand**

# %%
brand1_df = create_modelling_df(data=data, brand=1)
brand2_df = create_modelling_df(data=data, brand=2)
brand3_df = create_modelling_df(data=data, brand=3)
brandAll_df = create_modelling_df(data=data, brand=None)

# %%
def estimate_ols(X,y):
    """Estimate the OLS model
    
    If 'validate' is true, the function will return the OLS regression models when run on a training
    and validation set.
    
    Args:
        data (pd.DataFrame): output from `create_modelling_df` function
        
    Returns:
        results (fitted regression model)
    
    """
    X = sm.add_constant(X)
    model = sm.OLS(y,X)
    return model.fit()

# %%
from sklearn.metrics import mean_squared_error

X_train_b1, X_test_b1, y_train_b1, y_test_b1 = create_train_test_split(brand1_df)

b1_model_results = estimate_ols(X_train_b1,y_train_b1)

X = sm.add_constant(X_test_b1)
preds = b1_model_results.predict(X)
mean_squared_error(preds, y_test_b1)

# %%
print(b1_model_results.summary())

# %%
X_train_all, X_test_all, y_train_all, y_test_all = create_train_test_split(brandAll_df)

b1_model_results = estimate_ols(X_train_all,y_train_all)

X = sm.add_constant(X_test_all)
preds = b1_model_results.predict(X)
mean_squared_error(preds, y_test_all)

# %%
X = sm.add_constant(X_test_b1)
#b1_model_results.predict(X)

# %%
X_train, X_test, y_train, y_test = create_train_test_split(brand1_df)

# %%
plt.scatter(y = b1_model_results.resid, x=range(len(b1_model_results.resid)))

# %%
import scipy.stats as stats
sm.qqplot(b1_model_results.resid, stats.t, fit=True, line='45')
plt.show()

# %%
plt.scatter(x=b1_model_results.fittedvalues, y = y_train_b1)
plt.xlabel("Fitted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ------------------
# # Retrain Models on all data

# %%
model_b1 = sm.OLS(brand1_df.iloc[:,-1],sm.add_constant(brand1_df.iloc[:,:-1])).fit()
model_b2 = sm.OLS(brand2_df.iloc[:,-1],sm.add_constant(brand2_df.iloc[:,:-1])).fit()
model_b3 = sm.OLS(brand3_df.iloc[:,-1],sm.add_constant(brand3_df.iloc[:,:-1])).fit()
model_all = sm.OLS(brandAll_df.iloc[:,-1],sm.add_constant(brandAll_df.iloc[:,:-1])).fit()

# %%
model_all.summary()

# %% [markdown]
# ----------
#
# # Latex Outputs For Report
#
# Copy and paste output into the report

# %%
from IPython.display import display, Markdown, Latex, HTML
from stargazer.stargazer import Stargazer

# %%
display(HTML("<h3>Brand 1 model"))
Latex(Stargazer([model_b1]).render_latex())
